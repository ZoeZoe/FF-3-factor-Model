# %%
import pandas as pd
import calendar
import datetime
from utils import process_ff5_df

# %%
pf_sizem = pd.read_csv('../data/Portfolios_Formed_on_ME_monthly.csv')
#ff5m = pd.read_csv('../data/F-F_Research_Data_5_Factors_2x3_monthly.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-c307208235bc> in <module>
# ----> 1 pf_sizem = pd.read_csv('../data/Portfolios_Formed_on_ME_monthly.csv')
#       2 #ff5m = pd.read_csv('../data/F-F_Research_Data_5_Factors_2x3_monthly.csv')
#
# ...

# %%
ff5 = process_ff5_df(ff5m)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-38437409bea6> in <module>
# ----> 1 ff5 = process_ff5_df(ff5m)
#
# ~/codecommit/zoe/utils.py in process_ff5_df(df)
#      28     yymm = str(ff5['YYMM'].iloc[0])
#      29     if len(yymm) == 6:
# ---> 30         ff5['YYMM'] = ff5['YYMM'].apply(yymm2yymmdd_lastDayOfMonth)
#      31
#      32     elif len(str(ff5['YYMM'].iloc[0])) == 8:
#
# ~/miniconda3/envs/eqai/lib/python3.5/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ...

# %%
ff5
# Out:
#             Mkt-RF   SMB   HML   RMW   CMA
# YYMM
# 1963-07-31   -0.39 -0.47 -0.83  0.66 -1.15
# 1963-08-31    5.07 -0.79  1.67  0.39 -0.40
# 1963-09-30   -1.57 -0.48  0.18 -0.76  0.24
# 1963-10-31    2.53 -1.29 -0.10  2.75 -2.24
# 1963-11-30   -0.85 -0.84  1.71 -0.45  2.22
# 1963-12-31    1.83 -1.89 -0.12  0.08 -0.30
# 1964-01-31    2.24  0.08  1.59  0.22  1.50
# 1964-02-29    1.54  0.32  2.83  0.06  0.85
# 1964-03-31    1.41  1.41  3.32 -2.01  2.93
# 1964-04-30    0.10 -1.52 -0.55 -1.35 -1.08
# 1964-05-31    1.42 -0.68  1.98 -0.26  0.24
# 1964-06-30    1.27  0.09  0.68 -0.42  0.14
# 1964-07-31    1.74  0.53  0.68  0.14  1.84
# 1964-08-31   -1.44  0.30  0.09  0.06  0.36
# 1964-09-30    2.69 -0.31  1.65 -0.48  0.58
# 1964-10-31    0.59  0.88  1.14 -0.29  0.48
# 1964-11-30    0.00 -0.27 -1.98  0.60 -0.16
# 1964-12-31    0.03 -0.58 -2.55  1.13 -1.63
# 1965-01-31    3.54  2.49  0.18  0.84  0.11
# 1965-02-28    0.44  3.31  0.22  0.40 -0.69
# 1965-03-31   -1.34  2.03  1.09 -0.30  0.73
# ...
